# %%
# %pip install ultralytics
# %pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# %pip install opencv-python
# Out:
# Requirement already satisfied: ultralytics in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (8.3.34)
# Requirement already satisfied: numpy>=1.23.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from ultralytics) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from ultralytics) (3.8.3)
# Requirement already satisfied: opencv-python>=4.6.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from ultralytics) (4.10.0.84)
# Requirement already satisfied: pillow>=7.1.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from ultralytics) (10.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from ultralytics) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from ultralytics) (1.14.0)
# Requirement already satisfied: torch>=1.8.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from ultralytics) (2.5.1)
# Requirement already satisfied: torchvision>=0.9.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from ultralytics) (0.20.1)
# Requirement already satisfied: tqdm>=4.64.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from ultralytics) (4.66.5)
# Requirement already satisfied: psutil in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from ultralytics) (6.0.0)
# Requirement already satisfied: py-cpuinfo in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from ultralytics) (1.5.3)
# Requirement already satisfied: seaborn>=0.11.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from ultralytics) (0.13.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from ultralytics) (2.0.12)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas>=1.1.4->ultralytics) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests>=2.23.0->ultralytics) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests>=2.23.0->ultralytics) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests>=2.23.0->ultralytics) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests>=2.23.0->ultralytics) (2024.7.4)
# Requirement already satisfied: filelock in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Requirement already satisfied: networkx in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (3.3)
# Requirement already satisfied: jinja2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (3.1.4)
# Requirement already satisfied: fsspec in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (2024.6.1)
# Requirement already satisfied: setuptools in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (72.2.0)
# Requirement already satisfied: sympy==1.13.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.5)
# Note: you may need to restart the kernel to use updated packages.
# Looking in indexes: https://download.pytorch.org/whl/cu118
# Requirement already satisfied: torch in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (2.5.1)
# Requirement already satisfied: torchvision in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (0.20.1)
# ERROR: Could not find a version that satisfies the requirement torchaudio (from versions: none)
# ERROR: No matching distribution found for torchaudio
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: opencv-python in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from opencv-python) (1.26.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
# 라이브러리 임포트
import os
import json
import cv2
import torch
import shutil
from pathlib import Path
from ultralytics import YOLO

# CUDA 사용 가능 여부 확인
if torch.cuda.is_available():
   device = "cuda"
   print(f"CUDA를 사용하여 처리를 시작합니다. (GPU: {torch.cuda.get_device_name(0)})")
else:
   device = "cpu"
   print("CUDA를 사용할 수 없어 CPU로 처리를 시작합니다.")

def analyze_video_people_count(video_path, sample_interval=7, min_presence_ratio=0.3, min_size_ratio=0.1):
   """
   비디오에서 주 사용자 수만 검출
   Args:
       video_path: 비디오 파일 경로
       sample_interval: 몇 프레임마다 검사할지
       min_presence_ratio: 전체 시간 중 최소 등장 비율 (0~1)
       min_size_ratio: 화면 대비 최소 크기 비율 (0~1)
   """
   try:
       model = YOLO('yolov8s.pt').to(device)
       cap = cv2.VideoCapture(str(video_path))
       if not cap.isOpened():
           return 1

       frame_count = 0
       total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
       frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
       frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
       min_area = frame_width * frame_height * min_size_ratio

       # 각 사람별 등장 횟수 추적
       person_tracks = {}  # {track_id: count}
       
       print(f"\n{Path(video_path).name} 분석 중...")
       print(f"총 프레임 수: {total_frames}")
       
       while cap.isOpened():
           ret, frame = cap.read()
           if not ret:
               break

           frame_count += 1
           if frame_count % sample_interval != 0:
               continue

           if frame_count % (total_frames // 10) == 0:
               progress = (frame_count / total_frames) * 100
               print(f"진행률: {progress:.1f}%")

           results = model.track(frame, persist=True, classes=[0])  # tracking 모드 사용
           
           if results[0].boxes.id is not None:
               for box, track_id in zip(results[0].boxes.xywh, results[0].boxes.id):
                   # 박스 크기 계산
                   area = box[2] * box[3]  # width * height
                   track_id = int(track_id)
                   
                   # 충분히 큰 크기의 사람만 카운트
                   if area >= min_area:
                       person_tracks[track_id] = person_tracks.get(track_id, 0) + 1

       cap.release()

       # 충분한 시간 등장한 사람만 카운트
       min_frames = (total_frames / sample_interval) * min_presence_ratio
       main_people = sum(1 for count in person_tracks.values() if count >= min_frames)
       
       print(f"주 사용자 수: {main_people}명")
       return main_people

   except Exception as e:
       print(f"Error analyzing video {video_path}: {str(e)}")
       return 1

def process_folder(input_folder_path):
   """폴더 처리 메인 함수"""
   input_folder = Path(input_folder_path)
   
   # userNum이 1인 json만 필터링
   target_files = []
   print("\nJSON 파일 분석 중...")
   
   for json_file in input_folder.glob("*.json"):
       try:
           with open(json_file, 'r', encoding='utf-8') as f:
               data = json.load(f)
               if (data.get('annotations', {}).get('user_num', 0) == 1):
                   # 비디오 파일 확인 (여러 확장자 지원)
                   video_found = False
                   for ext in ['.mp4', '.avi', '.mov', '.mkv']:
                       video_file = json_file.with_suffix(ext)
                       if video_file.exists():
                           target_files.append((json_file, video_file))
                           video_found = True
                           break
                   if not video_found:
                       print(f"Warning: {json_file.name}에 대한 비디오 파일을 찾을 수 없습니다.")
       except Exception as e:
           print(f"Error processing {json_file}: {str(e)}")
           continue

   if not target_files:
       print("\n검토가 필요한 파일이 없습니다.")
       return

   print(f"\n검토 대상 파일 수: {len(target_files)}")

   need_fix_files = []
   for json_file, video_file in target_files:
       max_people = analyze_video_people_count(str(video_file))
       if max_people > 1:
           need_fix_files.append((json_file, video_file, max_people))

   # 수정이 필요한 파일이 있는 경우에만 결과 폴더 생성
   if need_fix_files:
       result_folder = input_folder.parent / f"{input_folder.name}_needFix"
       if result_folder.exists():
           shutil.rmtree(result_folder)
       result_folder.mkdir()
       print(f"\n결과 저장 폴더 생성: {result_folder}")

       # 파일 복사
       for json_file, video_file, _ in need_fix_files:
           shutil.copy2(json_file, result_folder)
           shutil.copy2(video_file, result_folder)

       print(f"\n처리 완료:")
       print(f"- 검토 대상 파일 수: {len(target_files)}")
       print(f"- 수정 필요 파일 수: {len(need_fix_files)}")
       print(f"\n수정이 필요한 파일이 {result_folder}에 복사되었습니다.")
       print("\n수정이 필요한 파일 목록:")
       for json_file, video_file, count in need_fix_files:
           print(f"- {json_file.name}: 검출된 주 사용자 수 = {count}명")
   else:
       print("\n처리 완료:")
       print(f"- 검토 대상 파일 수: {len(target_files)}")
       print("- 모든 파일의 userNum이 정상입니다.")

def get_folder_path():
   while True:
       folder_path = input("처리할 폴더 경로를 입력하세요: ").strip()
       
       # 경로에 따옴표가 있다면 제거
       folder_path = folder_path.strip('"').strip("'")
       
       if not folder_path:
           print("경로를 입력해주세요.")
           continue
           
       path = Path(folder_path)
       if not path.exists():
           print("존재하지 않는 경로입니다.")
           continue
       if not path.is_dir():
           print("폴더가 아닙니다.")
           continue
           
       return str(path)

# 메인 실행 부분
if __name__ == "__main__":
   print("YOLOv8s를 사용한 비디오 분석 프로그램")
   print("----------------------------------------")
   
   folder_path = get_folder_path()
   process_folder(folder_path)
# Out:
# CUDA를 사용할 수 없어 CPU로 처리를 시작합니다.
# YOLOv8s를 사용한 비디오 분석 프로그램
# ----------------------------------------
#
# JSON 파일 분석 중...
#
# 검토 대상 파일 수: 51
#
# 0028_1016200237.mp4 분석 중...
# 총 프레임 수: 1368
# requirements: Ultralytics requirement ['lapx>=0.5.2'] not found, attempting AutoUpdate...
# Requirement already satisfied: lapx>=0.5.2 in /opt/anaconda3/lib/python3.11/site-packages (0.5.11)
# Requirement already satisfied: numpy>=1.21.6 in /opt/anaconda3/lib/python3.11/site-packages (from lapx>=0.5.2) (1.26.4)
#
# requirements: AutoUpdate success ✅ 1.0s, installed 1 package: ['lapx>=0.5.2']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# Error analyzing video /Users/joyong-eun/Desktop/무제 폴더 2/28_1016/0028_1016200237.mp4: No module named 'lap'
#
# 0028_1016143929.mp4 분석 중...
# 총 프레임 수: 1174
# requirements: Ultralytics requirement ['lapx>=0.5.2'] not found, attempting AutoUpdate...
# Requirement already satisfied: lapx>=0.5.2 in /opt/anaconda3/lib/python3.11/site-packages (0.5.11)
# Requirement already satisfied: numpy>=1.21.6 in /opt/anaconda3/lib/python3.11/site-packages (from lapx>=0.5.2) (1.26.4)
#
# requirements: AutoUpdate success ✅ 0.6s, installed 1 package: ['lapx>=0.5.2']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# Error analyzing video /Users/joyong-eun/Desktop/무제 폴더 2/28_1016/0028_1016143929.mp4: No module named 'lap'
#
# 0028_1016103423.mp4 분석 중...
# 총 프레임 수: 733
# requirements: Ultralytics requirement ['lapx>=0.5.2'] not found, attempting AutoUpdate...
# Requirement already satisfied: lapx>=0.5.2 in /opt/anaconda3/lib/python3.11/site-packages (0.5.11)
# Requirement already satisfied: numpy>=1.21.6 in /opt/anaconda3/lib/python3.11/site-packages (from lapx>=0.5.2) (1.26.4)
#
# requirements: AutoUpdate success ✅ 0.6s, installed 1 package: ['lapx>=0.5.2']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# Error analyzing video /Users/joyong-eun/Desktop/무제 폴더 2/28_1016/0028_1016103423.mp4: No module named 'lap'
#
# 0028_1016142528.mp4 분석 중...
# 총 프레임 수: 475
# requirements: Ultralytics requirement ['lapx>=0.5.2'] not found, attempting AutoUpdate...
# Requirement already satisfied: lapx>=0.5.2 in /opt/anaconda3/lib/python3.11/site-packages (0.5.11)
# Requirement already satisfied: numpy>=1.21.6 in /opt/anaconda3/lib/python3.11/site-packages (from lapx>=0.5.2) (1.26.4)
#
# requirements: AutoUpdate success ✅ 0.6s, installed 1 package: ['lapx>=0.5.2']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# Error analyzing video /Users/joyong-eun/Desktop/무제 폴더 2/28_1016/0028_1016142528.mp4: No module named 'lap'
#
# 0028_1016184422.mp4 분석 중...
# 총 프레임 수: 4277
# requirements: Ultralytics requirement ['lapx>=0.5.2'] not found, attempting AutoUpdate...
# Requirement already satisfied: lapx>=0.5.2 in /opt/anaconda3/lib/python3.11/site-packages (0.5.11)
# Requirement already satisfied: numpy>=1.21.6 in /opt/anaconda3/lib/python3.11/site-packages (from lapx>=0.5.2) (1.26.4)
#
# requirements: AutoUpdate success ✅ 0.6s, installed 1 package: ['lapx>=0.5.2']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# Error analyzing video /Users/joyong-eun/Desktop/무제 폴더 2/28_1016/0028_1016184422.mp4: No module named 'lap'
#
# 0028_1016193426.mp4 분석 중...
# 총 프레임 수: 1090
# requirements: Ultralytics requirement ['lapx>=0.5.2'] not found, attempting AutoUpdate...
# Requirement already satisfied: lapx>=0.5.2 in /opt/anaconda3/lib/python3.11/site-packages (0.5.11)
# Requirement already satisfied: numpy>=1.21.6 in /opt/anaconda3/lib/python3.11/site-packages (from lapx>=0.5.2) (1.26.4)
#
# requirements: AutoUpdate success ✅ 0.6s, installed 1 package: ['lapx>=0.5.2']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# Error analyzing video /Users/joyong-eun/Desktop/무제 폴더 2/28_1016/0028_1016193426.mp4: No module named 'lap'
#
# 0028_1016193328.mp4 분석 중...
# 총 프레임 수: 880
# requirements: Ultralytics requirement ['lapx>=0.5.2'] not found, attempting AutoUpdate...
# Requirement already satisfied: lapx>=0.5.2 in /opt/anaconda3/lib/python3.11/site-packages (0.5.11)
# Requirement already satisfied: numpy>=1.21.6 in /opt/anaconda3/lib/python3.11/site-packages (from lapx>=0.5.2) (1.26.4)
#
# requirements: AutoUpdate success ✅ 0.6s, installed 1 package: ['lapx>=0.5.2']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# Error analyzing video /Users/joyong-eun/Desktop/무제 폴더 2/28_1016/0028_1016193328.mp4: No module named 'lap'
#
# 0028_1016183611.mp4 분석 중...
# 총 프레임 수: 788
# requirements: Ultralytics requirement ['lapx>=0.5.2'] not found, attempting AutoUpdate...
# Requirement already satisfied: lapx>=0.5.2 in /opt/anaconda3/lib/python3.11/site-packages (0.5.11)
# Requirement already satisfied: numpy>=1.21.6 in /opt/anaconda3/lib/python3.11/site-packages (from lapx>=0.5.2) (1.26.4)
#
# requirements: AutoUpdate success ✅ 0.6s, installed 1 package: ['lapx>=0.5.2']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# Error analyzing video /Users/joyong-eun/Desktop/무제 폴더 2/28_1016/0028_1016183611.mp4: No module named 'lap'
#
# 0028_1016124526.mp4 분석 중...
# 총 프레임 수: 1280
# requirements: Ultralytics requirement ['lapx>=0.5.2'] not found, attempting AutoUpdate...
# Requirement already satisfied: lapx>=0.5.2 in /opt/anaconda3/lib/python3.11/site-packages (0.5.11)
# Requirement already satisfied: numpy>=1.21.6 in /opt/anaconda3/lib/python3.11/site-packages (from lapx>=0.5.2) (1.26.4)
#
# requirements: AutoUpdate success ✅ 0.6s, installed 1 package: ['lapx>=0.5.2']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# Error analyzing video /Users/joyong-eun/Desktop/무제 폴더 2/28_1016/0028_1016124526.mp4: No module named 'lap'
#
# 0028_1016173628.mp4 분석 중...
# 총 프레임 수: 667
# requirements: Ultralytics requirement ['lapx>=0.5.2'] not found, attempting AutoUpdate...
# Requirement already satisfied: lapx>=0.5.2 in /opt/anaconda3/lib/python3.11/site-packages (0.5.11)
# Requirement already satisfied: numpy>=1.21.6 in /opt/anaconda3/lib/python3.11/site-packages (from lapx>=0.5.2) (1.26.4)
#
# requirements: AutoUpdate success ✅ 0.6s, installed 1 package: ['lapx>=0.5.2']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# Error analyzing video /Users/joyong-eun/Desktop/무제 폴더 2/28_1016/0028_1016173628.mp4: No module named 'lap'
#
# 0028_1016201407.mp4 분석 중...
# 총 프레임 수: 912
# requirements: Ultralytics requirement ['lapx>=0.5.2'] not found, attempting AutoUpdate...
# Requirement already satisfied: lapx>=0.5.2 in /opt/anaconda3/lib/python3.11/site-packages (0.5.11)
# Requirement already satisfied: numpy>=1.21.6 in /opt/anaconda3/lib/python3.11/site-packages (from lapx>=0.5.2) (1.26.4)
#
# requirements: AutoUpdate success ✅ 0.6s, installed 1 package: ['lapx>=0.5.2']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# Error analyzing video /Users/joyong-eun/Desktop/무제 폴더 2/28_1016/0028_1016201407.mp4: No module named 'lap'
#
# 0028_1016120821.mp4 분석 중...
# 총 프레임 수: 686
# requirements: Ultralytics requirement ['lapx>=0.5.2'] not found, attempting AutoUpdate...
# Requirement already satisfied: lapx>=0.5.2 in /opt/anaconda3/lib/python3.11/site-packages (0.5.11)
# Requirement already satisfied: numpy>=1.21.6 in /opt/anaconda3/lib/python3.11/site-packages (from lapx>=0.5.2) (1.26.4)
#
# requirements: AutoUpdate success ✅ 0.6s, installed 1 package: ['lapx>=0.5.2']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# Error analyzing video /Users/joyong-eun/Desktop/무제 폴더 2/28_1016/0028_1016120821.mp4: No module named 'lap'
#
# 0028_1016131027.mp4 분석 중...
# 총 프레임 수: 415
# requirements: Ultralytics requirement ['lapx>=0.5.2'] not found, attempting AutoUpdate...
# Requirement already satisfied: lapx>=0.5.2 in /opt/anaconda3/lib/python3.11/site-packages (0.5.11)
# Requirement already satisfied: numpy>=1.21.6 in /opt/anaconda3/lib/python3.11/site-packages (from lapx>=0.5.2) (1.26.4)
#
# requirements: AutoUpdate success ✅ 0.6s, installed 1 package: ['lapx>=0.5.2']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# Error analyzing video /Users/joyong-eun/Desktop/무제 폴더 2/28_1016/0028_1016131027.mp4: No module named 'lap'
#
# 0028_1016121154.mp4 분석 중...
# 총 프레임 수: 1438
# requirements: Ultralytics requirement ['lapx>=0.5.2'] not found, attempting AutoUpdate...
# Requirement already satisfied: lapx>=0.5.2 in /opt/anaconda3/lib/python3.11/site-packages (0.5.11)
# Requirement already satisfied: numpy>=1.21.6 in /opt/anaconda3/lib/python3.11/site-packages (from lapx>=0.5.2) (1.26.4)
#
# requirements: AutoUpdate success ✅ 0.6s, installed 1 package: ['lapx>=0.5.2']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# Error analyzing video /Users/joyong-eun/Desktop/무제 폴더 2/28_1016/0028_1016121154.mp4: No module named 'lap'
#
# 0028_1016172131.mp4 분석 중...
# 총 프레임 수: 856
# requirements: Ultralytics requirement ['lapx>=0.5.2'] not found, attempting AutoUpdate...
# Requirement already satisfied: lapx>=0.5.2 in /opt/anaconda3/lib/python3.11/site-packages (0.5.11)
# Requirement already satisfied: numpy>=1.21.6 in /opt/anaconda3/lib/python3.11/site-packages (from lapx>=0.5.2) (1.26.4)
#
# requirements: AutoUpdate success ✅ 0.6s, installed 1 package: ['lapx>=0.5.2']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# Error analyzing video /Users/joyong-eun/Desktop/무제 폴더 2/28_1016/0028_1016172131.mp4: No module named 'lap'
#
# 0028_1016142559.mp4 분석 중...
# 총 프레임 수: 1788
# requirements: Ultralytics requirement ['lapx>=0.5.2'] not found, attempting AutoUpdate...
# Requirement already satisfied: lapx>=0.5.2 in /opt/anaconda3/lib/python3.11/site-packages (0.5.11)
# Requirement already satisfied: numpy>=1.21.6 in /opt/anaconda3/lib/python3.11/site-packages (from lapx>=0.5.2) (1.26.4)
#
# requirements: AutoUpdate success ✅ 0.6s, installed 1 package: ['lapx>=0.5.2']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# Error analyzing video /Users/joyong-eun/Desktop/무제 폴더 2/28_1016/0028_1016142559.mp4: No module named 'lap'
#
# 0028_1016140732.mp4 분석 중...
# 총 프레임 수: 547
# requirements: Ultralytics requirement ['lapx>=0.5.2'] not found, attempting AutoUpdate...
# Requirement already satisfied: lapx>=0.5.2 in /opt/anaconda3/lib/python3.11/site-packages (0.5.11)
# Requirement already satisfied: numpy>=1.21.6 in /opt/anaconda3/lib/python3.11/site-packages (from lapx>=0.5.2) (1.26.4)
#
# requirements: AutoUpdate success ✅ 0.6s, installed 1 package: ['lapx>=0.5.2']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# Error analyzing video /Users/joyong-eun/Desktop/무제 폴더 2/28_1016/0028_1016140732.mp4: No module named 'lap'
#
# 0028_1016152934.mp4 분석 중...
# 총 프레임 수: 1774
# requirements: Ultralytics requirement ['lapx>=0.5.2'] not found, attempting AutoUpdate...
# Requirement already satisfied: lapx>=0.5.2 in /opt/anaconda3/lib/python3.11/site-packages (0.5.11)
# Requirement already satisfied: numpy>=1.21.6 in /opt/anaconda3/lib/python3.11/site-packages (from lapx>=0.5.2) (1.26.4)
#
# requirements: AutoUpdate success ✅ 0.6s, installed 1 package: ['lapx>=0.5.2']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# Error analyzing video /Users/joyong-eun/Desktop/무제 폴더 2/28_1016/0028_1016152934.mp4: No module named 'lap'
#
# 0028_1016160235.mp4 분석 중...
# 총 프레임 수: 347
# requirements: Ultralytics requirement ['lapx>=0.5.2'] not found, attempting AutoUpdate...
# Requirement already satisfied: lapx>=0.5.2 in /opt/anaconda3/lib/python3.11/site-packages (0.5.11)
# Requirement already satisfied: numpy>=1.21.6 in /opt/anaconda3/lib/python3.11/site-packages (from lapx>=0.5.2) (1.26.4)
#
# requirements: AutoUpdate success ✅ 0.6s, installed 1 package: ['lapx>=0.5.2']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# Error analyzing video /Users/joyong-eun/Desktop/무제 폴더 2/28_1016/0028_1016160235.mp4: No module named 'lap'
#
# 0028_1016130305.mp4 분석 중...
# 총 프레임 수: 814
# requirements: Ultralytics requirement ['lapx>=0.5.2'] not found, attempting AutoUpdate...
# Requirement already satisfied: lapx>=0.5.2 in /opt/anaconda3/lib/python3.11/site-packages (0.5.11)
# Requirement already satisfied: numpy>=1.21.6 in /opt/anaconda3/lib/python3.11/site-packages (from lapx>=0.5.2) (1.26.4)
#
# requirements: AutoUpdate success ✅ 0.6s, installed 1 package: ['lapx>=0.5.2']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# Error analyzing video /Users/joyong-eun/Desktop/무제 폴더 2/28_1016/0028_1016130305.mp4: No module named 'lap'
#
# 0028_1016134346.mp4 분석 중...
# 총 프레임 수: 386
# requirements: Ultralytics requirement ['lapx>=0.5.2'] not found, attempting AutoUpdate...
# Requirement already satisfied: lapx>=0.5.2 in /opt/anaconda3/lib/python3.11/site-packages (0.5.11)
# Requirement already satisfied: numpy>=1.21.6 in /opt/anaconda3/lib/python3.11/site-packages (from lapx>=0.5.2) (1.26.4)
#
# requirements: AutoUpdate success ✅ 0.6s, installed 1 package: ['lapx>=0.5.2']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# Error analyzing video /Users/joyong-eun/Desktop/무제 폴더 2/28_1016/0028_1016134346.mp4: No module named 'lap'
#
# 0028_1016124429.mp4 분석 중...
# 총 프레임 수: 422
# requirements: Ultralytics requirement ['lapx>=0.5.2'] not found, attempting AutoUpdate...
# Requirement already satisfied: lapx>=0.5.2 in /opt/anaconda3/lib/python3.11/site-packages (0.5.11)
# Requirement already satisfied: numpy>=1.21.6 in /opt/anaconda3/lib/python3.11/site-packages (from lapx>=0.5.2) (1.26.4)
#
# requirements: AutoUpdate success ✅ 0.6s, installed 1 package: ['lapx>=0.5.2']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# Error analyzing video /Users/joyong-eun/Desktop/무제 폴더 2/28_1016/0028_1016124429.mp4: No module named 'lap'
#
# 0028_1016121410.mp4 분석 중...
# 총 프레임 수: 199
# requirements: Ultralytics requirement ['lapx>=0.5.2'] not found, attempting AutoUpdate...
# Requirement already satisfied: lapx>=0.5.2 in /opt/anaconda3/lib/python3.11/site-packages (0.5.11)
# Requirement already satisfied: numpy>=1.21.6 in /opt/anaconda3/lib/python3.11/site-packages (from lapx>=0.5.2) (1.26.4)
#
# requirements: AutoUpdate success ✅ 0.6s, installed 1 package: ['lapx>=0.5.2']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# Error analyzing video /Users/joyong-eun/Desktop/무제 폴더 2/28_1016/0028_1016121410.mp4: No module named 'lap'
#
# 0028_1016123401.mp4 분석 중...
# 총 프레임 수: 1034
# requirements: Ultralytics requirement ['lapx>=0.5.2'] not found, attempting AutoUpdate...
# Requirement already satisfied: lapx>=0.5.2 in /opt/anaconda3/lib/python3.11/site-packages (0.5.11)
# Requirement already satisfied: numpy>=1.21.6 in /opt/anaconda3/lib/python3.11/site-packages (from lapx>=0.5.2) (1.26.4)
#
# requirements: AutoUpdate success ✅ 0.6s, installed 1 package: ['lapx>=0.5.2']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# Error analyzing video /Users/joyong-eun/Desktop/무제 폴더 2/28_1016/0028_1016123401.mp4: No module named 'lap'
#
# 0028_1016191719.mp4 분석 중...
# 총 프레임 수: 918
# requirements: Ultralytics requirement ['lapx>=0.5.2'] not found, attempting AutoUpdate...
# Requirement already satisfied: lapx>=0.5.2 in /opt/anaconda3/lib/python3.11/site-packages (0.5.11)
# Requirement already satisfied: numpy>=1.21.6 in /opt/anaconda3/lib/python3.11/site-packages (from lapx>=0.5.2) (1.26.4)
#
# requirements: AutoUpdate success ✅ 0.6s, installed 1 package: ['lapx>=0.5.2']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# Error analyzing video /Users/joyong-eun/Desktop/무제 폴더 2/28_1016/0028_1016191719.mp4: No module named 'lap'
#
# 0028_1016200139.mp4 분석 중...
# 총 프레임 수: 876
# requirements: Ultralytics requirement ['lapx>=0.5.2'] not found, attempting AutoUpdate...
# Requirement already satisfied: lapx>=0.5.2 in /opt/anaconda3/lib/python3.11/site-packages (0.5.11)
# Requirement already satisfied: numpy>=1.21.6 in /opt/anaconda3/lib/python3.11/site-packages (from lapx>=0.5.2) (1.26.4)
#
# requirements: AutoUpdate success ✅ 0.6s, installed 1 package: ['lapx>=0.5.2']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# Error analyzing video /Users/joyong-eun/Desktop/무제 폴더 2/28_1016/0028_1016200139.mp4: No module named 'lap'
#
# 0028_1016173839.mp4 분석 중...
# 총 프레임 수: 1308
# requirements: Ultralytics requirement ['lapx>=0.5.2'] not found, attempting AutoUpdate...
# Requirement already satisfied: lapx>=0.5.2 in /opt/anaconda3/lib/python3.11/site-packages (0.5.11)
# Requirement already satisfied: numpy>=1.21.6 in /opt/anaconda3/lib/python3.11/site-packages (from lapx>=0.5.2) (1.26.4)
#
# requirements: AutoUpdate success ✅ 0.6s, installed 1 package: ['lapx>=0.5.2']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# Error analyzing video /Users/joyong-eun/Desktop/무제 폴더 2/28_1016/0028_1016173839.mp4: No module named 'lap'
#
# 0028_1016140836.mp4 분석 중...
# 총 프레임 수: 515
# requirements: Ultralytics requirement ['lapx>=0.5.2'] not found, attempting AutoUpdate...
# Requirement already satisfied: lapx>=0.5.2 in /opt/anaconda3/lib/python3.11/site-packages (0.5.11)
# Requirement already satisfied: numpy>=1.21.6 in /opt/anaconda3/lib/python3.11/site-packages (from lapx>=0.5.2) (1.26.4)
#
# requirements: AutoUpdate success ✅ 0.6s, installed 1 package: ['lapx>=0.5.2']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# Error analyzing video /Users/joyong-eun/Desktop/무제 폴더 2/28_1016/0028_1016140836.mp4: No module named 'lap'
#
# 0028_1016174128.mp4 분석 중...
# 총 프레임 수: 1937
# requirements: Ultralytics requirement ['lapx>=0.5.2'] not found, attempting AutoUpdate...
# Requirement already satisfied: lapx>=0.5.2 in /opt/anaconda3/lib/python3.11/site-packages (0.5.11)
# Requirement already satisfied: numpy>=1.21.6 in /opt/anaconda3/lib/python3.11/site-packages (from lapx>=0.5.2) (1.26.4)
#
# requirements: AutoUpdate success ✅ 0.6s, installed 1 package: ['lapx>=0.5.2']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# Error analyzing video /Users/joyong-eun/Desktop/무제 폴더 2/28_1016/0028_1016174128.mp4: No module named 'lap'
#
# 0028_1016123822.mp4 분석 중...
# 총 프레임 수: 1210
# requirements: Ultralytics requirement ['lapx>=0.5.2'] not found, attempting AutoUpdate...
# Requirement already satisfied: lapx>=0.5.2 in /opt/anaconda3/lib/python3.11/site-packages (0.5.11)
# Requirement already satisfied: numpy>=1.21.6 in /opt/anaconda3/lib/python3.11/site-packages (from lapx>=0.5.2) (1.26.4)
#
# requirements: AutoUpdate success ✅ 0.6s, installed 1 package: ['lapx>=0.5.2']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# Error analyzing video /Users/joyong-eun/Desktop/무제 폴더 2/28_1016/0028_1016123822.mp4: No module named 'lap'
#
# 0028_1016180652.mp4 분석 중...
# 총 프레임 수: 657
# requirements: Ultralytics requirement ['lapx>=0.5.2'] not found, attempting AutoUpdate...
# Requirement already satisfied: lapx>=0.5.2 in /opt/anaconda3/lib/python3.11/site-packages (0.5.11)
# Requirement already satisfied: numpy>=1.21.6 in /opt/anaconda3/lib/python3.11/site-packages (from lapx>=0.5.2) (1.26.4)
#
# requirements: AutoUpdate success ✅ 0.6s, installed 1 package: ['lapx>=0.5.2']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# Error analyzing video /Users/joyong-eun/Desktop/무제 폴더 2/28_1016/0028_1016180652.mp4: No module named 'lap'
#
# 0028_1016130424.mp4 분석 중...
# 총 프레임 수: 660
# requirements: Ultralytics requirement ['lapx>=0.5.2'] not found, attempting AutoUpdate...
# Requirement already satisfied: lapx>=0.5.2 in /opt/anaconda3/lib/python3.11/site-packages (0.5.11)
# Requirement already satisfied: numpy>=1.21.6 in /opt/anaconda3/lib/python3.11/site-packages (from lapx>=0.5.2) (1.26.4)
#
# requirements: AutoUpdate success ✅ 0.6s, installed 1 package: ['lapx>=0.5.2']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# Error analyzing video /Users/joyong-eun/Desktop/무제 폴더 2/28_1016/0028_1016130424.mp4: No module named 'lap'
#
# 0028_1016115951.mp4 분석 중...
# 총 프레임 수: 773
# requirements: Ultralytics requirement ['lapx>=0.5.2'] not found, attempting AutoUpdate...
# Requirement already satisfied: lapx>=0.5.2 in /opt/anaconda3/lib/python3.11/site-packages (0.5.11)
# Requirement already satisfied: numpy>=1.21.6 in /opt/anaconda3/lib/python3.11/site-packages (from lapx>=0.5.2) (1.26.4)
#
# requirements: AutoUpdate success ✅ 0.6s, installed 1 package: ['lapx>=0.5.2']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# Error analyzing video /Users/joyong-eun/Desktop/무제 폴더 2/28_1016/0028_1016115951.mp4: No module named 'lap'
#
# 0028_1016175405.mp4 분석 중...
# 총 프레임 수: 720
# requirements: Ultralytics requirement ['lapx>=0.5.2'] not found, attempting AutoUpdate...
# Requirement already satisfied: lapx>=0.5.2 in /opt/anaconda3/lib/python3.11/site-packages (0.5.11)
# Requirement already satisfied: numpy>=1.21.6 in /opt/anaconda3/lib/python3.11/site-packages (from lapx>=0.5.2) (1.26.4)
#
# requirements: AutoUpdate success ✅ 0.6s, installed 1 package: ['lapx>=0.5.2']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# Error analyzing video /Users/joyong-eun/Desktop/무제 폴더 2/28_1016/0028_1016175405.mp4: No module named 'lap'
#
# 0028_1016143130.mp4 분석 중...
# 총 프레임 수: 1044
# requirements: Ultralytics requirement ['lapx>=0.5.2'] not found, attempting AutoUpdate...
# Requirement already satisfied: lapx>=0.5.2 in /opt/anaconda3/lib/python3.11/site-packages (0.5.11)
# Requirement already satisfied: numpy>=1.21.6 in /opt/anaconda3/lib/python3.11/site-packages (from lapx>=0.5.2) (1.26.4)
#
# requirements: AutoUpdate success ✅ 0.6s, installed 1 package: ['lapx>=0.5.2']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# Error analyzing video /Users/joyong-eun/Desktop/무제 폴더 2/28_1016/0028_1016143130.mp4: No module named 'lap'
#
# 0028_1016172821.mp4 분석 중...
# 총 프레임 수: 390
# requirements: Ultralytics requirement ['lapx>=0.5.2'] not found, attempting AutoUpdate...
# Requirement already satisfied: lapx>=0.5.2 in /opt/anaconda3/lib/python3.11/site-packages (0.5.11)
# Requirement already satisfied: numpy>=1.21.6 in /opt/anaconda3/lib/python3.11/site-packages (from lapx>=0.5.2) (1.26.4)
#
# requirements: AutoUpdate success ✅ 0.6s, installed 1 package: ['lapx>=0.5.2']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# Error analyzing video /Users/joyong-eun/Desktop/무제 폴더 2/28_1016/0028_1016172821.mp4: No module named 'lap'
#
# 0028_1016121757.mp4 분석 중...
# 총 프레임 수: 829
# requirements: Ultralytics requirement ['lapx>=0.5.2'] not found, attempting AutoUpdate...
# Requirement already satisfied: lapx>=0.5.2 in /opt/anaconda3/lib/python3.11/site-packages (0.5.11)
# Requirement already satisfied: numpy>=1.21.6 in /opt/anaconda3/lib/python3.11/site-packages (from lapx>=0.5.2) (1.26.4)
#
# requirements: AutoUpdate success ✅ 0.6s, installed 1 package: ['lapx>=0.5.2']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# Error analyzing video /Users/joyong-eun/Desktop/무제 폴더 2/28_1016/0028_1016121757.mp4: No module named 'lap'
#
# 0028_1016121428.mp4 분석 중...
# 총 프레임 수: 567
# requirements: Ultralytics requirement ['lapx>=0.5.2'] not found, attempting AutoUpdate...
# Requirement already satisfied: lapx>=0.5.2 in /opt/anaconda3/lib/python3.11/site-packages (0.5.11)
# Requirement already satisfied: numpy>=1.21.6 in /opt/anaconda3/lib/python3.11/site-packages (from lapx>=0.5.2) (1.26.4)
#
# requirements: AutoUpdate success ✅ 0.6s, installed 1 package: ['lapx>=0.5.2']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# Error analyzing video /Users/joyong-eun/Desktop/무제 폴더 2/28_1016/0028_1016121428.mp4: No module named 'lap'
#
# 0028_1016131054.mp4 분석 중...
# 총 프레임 수: 444
# requirements: Ultralytics requirement ['lapx>=0.5.2'] not found, attempting AutoUpdate...
# Requirement already satisfied: lapx>=0.5.2 in /opt/anaconda3/lib/python3.11/site-packages (0.5.11)
# Requirement already satisfied: numpy>=1.21.6 in /opt/anaconda3/lib/python3.11/site-packages (from lapx>=0.5.2) (1.26.4)
#
# requirements: AutoUpdate success ✅ 0.6s, installed 1 package: ['lapx>=0.5.2']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# Error analyzing video /Users/joyong-eun/Desktop/무제 폴더 2/28_1016/0028_1016131054.mp4: No module named 'lap'
#
# 0028_1016173401.mp4 분석 중...
# 총 프레임 수: 1093
# requirements: Ultralytics requirement ['lapx>=0.5.2'] not found, attempting AutoUpdate...
# Requirement already satisfied: lapx>=0.5.2 in /opt/anaconda3/lib/python3.11/site-packages (0.5.11)
# Requirement already satisfied: numpy>=1.21.6 in /opt/anaconda3/lib/python3.11/site-packages (from lapx>=0.5.2) (1.26.4)
#
# requirements: AutoUpdate success ✅ 0.6s, installed 1 package: ['lapx>=0.5.2']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# Error analyzing video /Users/joyong-eun/Desktop/무제 폴더 2/28_1016/0028_1016173401.mp4: No module named 'lap'
#
# 0028_1016182414.mp4 분석 중...
# 총 프레임 수: 989
# requirements: Ultralytics requirement ['lapx>=0.5.2'] not found, attempting AutoUpdate...
# Requirement already satisfied: lapx>=0.5.2 in /opt/anaconda3/lib/python3.11/site-packages (0.5.11)
# Requirement already satisfied: numpy>=1.21.6 in /opt/anaconda3/lib/python3.11/site-packages (from lapx>=0.5.2) (1.26.4)
#
# requirements: AutoUpdate success ✅ 0.6s, installed 1 package: ['lapx>=0.5.2']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# Error analyzing video /Users/joyong-eun/Desktop/무제 폴더 2/28_1016/0028_1016182414.mp4: No module named 'lap'
#
# 0028_1016151209.mp4 분석 중...
# 총 프레임 수: 2315
# requirements: Ultralytics requirement ['lapx>=0.5.2'] not found, attempting AutoUpdate...
# Requirement already satisfied: lapx>=0.5.2 in /opt/anaconda3/lib/python3.11/site-packages (0.5.11)
# Requirement already satisfied: numpy>=1.21.6 in /opt/anaconda3/lib/python3.11/site-packages (from lapx>=0.5.2) (1.26.4)
#
# requirements: AutoUpdate success ✅ 0.6s, installed 1 package: ['lapx>=0.5.2']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# Error analyzing video /Users/joyong-eun/Desktop/무제 폴더 2/28_1016/0028_1016151209.mp4: No module named 'lap'
#
# 0028_1016122048.mp4 분석 중...
# 총 프레임 수: 1391
# requirements: Ultralytics requirement ['lapx>=0.5.2'] not found, attempting AutoUpdate...
# Requirement already satisfied: lapx>=0.5.2 in /opt/anaconda3/lib/python3.11/site-packages (0.5.11)
# Requirement already satisfied: numpy>=1.21.6 in /opt/anaconda3/lib/python3.11/site-packages (from lapx>=0.5.2) (1.26.4)
#
# requirements: AutoUpdate success ✅ 0.6s, installed 1 package: ['lapx>=0.5.2']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# Error analyzing video /Users/joyong-eun/Desktop/무제 폴더 2/28_1016/0028_1016122048.mp4: No module named 'lap'
#
# 0028_1016123659.mp4 분석 중...
# 총 프레임 수: 1253
# requirements: Ultralytics requirement ['lapx>=0.5.2'] not found, attempting AutoUpdate...
# Requirement already satisfied: lapx>=0.5.2 in /opt/anaconda3/lib/python3.11/site-packages (0.5.11)
# Requirement already satisfied: numpy>=1.21.6 in /opt/anaconda3/lib/python3.11/site-packages (from lapx>=0.5.2) (1.26.4)
#
# requirements: AutoUpdate success ✅ 0.6s, installed 1 package: ['lapx>=0.5.2']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# Error analyzing video /Users/joyong-eun/Desktop/무제 폴더 2/28_1016/0028_1016123659.mp4: No module named 'lap'
#
# 0028_1016182809.mp4 분석 중...
# 총 프레임 수: 984
# requirements: Ultralytics requirement ['lapx>=0.5.2'] not found, attempting AutoUpdate...
# Requirement already satisfied: lapx>=0.5.2 in /opt/anaconda3/lib/python3.11/site-packages (0.5.11)
# Requirement already satisfied: numpy>=1.21.6 in /opt/anaconda3/lib/python3.11/site-packages (from lapx>=0.5.2) (1.26.4)
#
# requirements: AutoUpdate success ✅ 0.6s, installed 1 package: ['lapx>=0.5.2']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# Error analyzing video /Users/joyong-eun/Desktop/무제 폴더 2/28_1016/0028_1016182809.mp4: No module named 'lap'
#
# 0028_1016124457.mp4 분석 중...
# 총 프레임 수: 433
# requirements: Ultralytics requirement ['lapx>=0.5.2'] not found, attempting AutoUpdate...
# Requirement already satisfied: lapx>=0.5.2 in /opt/anaconda3/lib/python3.11/site-packages (0.5.11)
# Requirement already satisfied: numpy>=1.21.6 in /opt/anaconda3/lib/python3.11/site-packages (from lapx>=0.5.2) (1.26.4)
#
# requirements: AutoUpdate success ✅ 0.6s, installed 1 package: ['lapx>=0.5.2']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# Error analyzing video /Users/joyong-eun/Desktop/무제 폴더 2/28_1016/0028_1016124457.mp4: No module named 'lap'
#
# 0028_1016131706.mp4 분석 중...
# 총 프레임 수: 967
# requirements: Ultralytics requirement ['lapx>=0.5.2'] not found, attempting AutoUpdate...
# Requirement already satisfied: lapx>=0.5.2 in /opt/anaconda3/lib/python3.11/site-packages (0.5.11)
# Requirement already satisfied: numpy>=1.21.6 in /opt/anaconda3/lib/python3.11/site-packages (from lapx>=0.5.2) (1.26.4)
#
# requirements: AutoUpdate success ✅ 0.6s, installed 1 package: ['lapx>=0.5.2']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# Error analyzing video /Users/joyong-eun/Desktop/무제 폴더 2/28_1016/0028_1016131706.mp4: No module named 'lap'
#
# 0028_1016124733.mp4 분석 중...
# 총 프레임 수: 4052
# requirements: Ultralytics requirement ['lapx>=0.5.2'] not found, attempting AutoUpdate...
# Requirement already satisfied: lapx>=0.5.2 in /opt/anaconda3/lib/python3.11/site-packages (0.5.11)
# Requirement already satisfied: numpy>=1.21.6 in /opt/anaconda3/lib/python3.11/site-packages (from lapx>=0.5.2) (1.26.4)
#
# requirements: AutoUpdate success ✅ 0.6s, installed 1 package: ['lapx>=0.5.2']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# Error analyzing video /Users/joyong-eun/Desktop/무제 폴더 2/28_1016/0028_1016124733.mp4: No module named 'lap'
#
# 0028_1016120907.mp4 분석 중...
# 총 프레임 수: 1204
# requirements: Ultralytics requirement ['lapx>=0.5.2'] not found, attempting AutoUpdate...
# Requirement already satisfied: lapx>=0.5.2 in /opt/anaconda3/lib/python3.11/site-packages (0.5.11)
# Requirement already satisfied: numpy>=1.21.6 in /opt/anaconda3/lib/python3.11/site-packages (from lapx>=0.5.2) (1.26.4)
#
# requirements: AutoUpdate success ✅ 0.6s, installed 1 package: ['lapx>=0.5.2']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# Error analyzing video /Users/joyong-eun/Desktop/무제 폴더 2/28_1016/0028_1016120907.mp4: No module named 'lap'
#
# 0028_1016122845.mp4 분석 중...
# 총 프레임 수: 487
# requirements: Ultralytics requirement ['lapx>=0.5.2'] not found, attempting AutoUpdate...
# Requirement already satisfied: lapx>=0.5.2 in /opt/anaconda3/lib/python3.11/site-packages (0.5.11)
# Requirement already satisfied: numpy>=1.21.6 in /opt/anaconda3/lib/python3.11/site-packages (from lapx>=0.5.2) (1.26.4)
#
# requirements: AutoUpdate success ✅ 0.6s, installed 1 package: ['lapx>=0.5.2']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# Error analyzing video /Users/joyong-eun/Desktop/무제 폴더 2/28_1016/0028_1016122845.mp4: No module named 'lap'
#
# 0028_1016153906.mp4 분석 중...
# 총 프레임 수: 1746
# requirements: Ultralytics requirement ['lapx>=0.5.2'] not found, attempting AutoUpdate...
# Requirement already satisfied: lapx>=0.5.2 in /opt/anaconda3/lib/python3.11/site-packages (0.5.11)
# Requirement already satisfied: numpy>=1.21.6 in /opt/anaconda3/lib/python3.11/site-packages (from lapx>=0.5.2) (1.26.4)
#
# requirements: AutoUpdate success ✅ 0.6s, installed 1 package: ['lapx>=0.5.2']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# Error analyzing video /Users/joyong-eun/Desktop/무제 폴더 2/28_1016/0028_1016153906.mp4: No module named 'lap'
#
# 처리 완료:
# - 검토 대상 파일 수: 51
# - 모든 파일의 userNum이 정상입니다.
